# %% [markdown]
# ## DECISION TREES
# ![image.png](attachment:80acd62d-167f-4966-ad45-ce786f31fe64.png)

# %%
import numpy as np 
# positive label distribution node  
parents_node = 10 /10+6
child_1 = 8/8+2
child_2 = 2/4+2


#entropy 
h_parents = -parents_node *log(parents_node) -( 1-parents_node)*(1-parents_node)
h_parents
# Out:
# ------------------------------------------------
# NameError      Traceback (most recent call last)
# Cell In[2], line 9
#       5 child_2 = 2/4+2
#       8 #entropy
# ----> 9 h_parents = -parents_node *log(parents_node) - 1-parents_node*(1-parents_node)
#      10 h_parents
#
# NameError: name 'log' is not defined
