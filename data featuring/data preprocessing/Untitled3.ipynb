# %% [markdown]
# ![image.png](attachment:28d2bffa-084b-468b-bd85-ac660def97c0.png)

# %% [markdown]
# ## decision tree classfier

# %%
training_data = [
    ['Green', 3, 'Apple'],
    ['Yellow', 3, 'Apple'],
    ['Red', 1, 'Grape'],
    ['Red', 1, 'Grape'],
    ['Yellow', 3, 'Lemon'],
]

# %%
#columns labels
# These are used only to print the tree.
header = ["color","diameter","label"]
